# %%
# !pip install prophet
# Out:
# Requirement already satisfied: prophet in /usr/local/lib/python3.10/dist-packages (1.1.5)
# Requirement already satisfied: cmdstanpy>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (1.2.1)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (1.25.2)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from prophet) (3.7.1)
# Requirement already satisfied: pandas>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (1.5.3)
# Requirement already satisfied: holidays>=0.25 in /usr/local/lib/python3.10/dist-packages (from prophet) (0.45)
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/lib/python3.10/dist-packages (from prophet) (4.66.2)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from prophet) (6.3.2)
# Requirement already satisfied: stanio~=0.3.0 in /usr/local/lib/python3.10/dist-packages (from cmdstanpy>=1.0.4->prophet) (0.3.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from holidays>=0.25->prophet) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (3.1.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.4->prophet) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->holidays>=0.25->prophet) (1.16.0)

# %%
from prophet import Prophet

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.optimize import minimize, LinearConstraint, Bounds

# %%
file_path = "/content/drive/MyDrive/Cleaned_Data/export_data.csv"

df = pd.read_csv(file_path)
#df["Date"] = pd.to_datetime(df["Date"])
df.head(2)
# Out:
#          Date      AAPL      ABCB      ACGL      ADBE       ADI       ADP  \
# 0  2000-01-03  0.088754  0.011765 -0.089109 -0.025093 -0.030242 -0.034803
# 1  2000-01-04 -0.084310 -0.011628 -0.005435 -0.083889 -0.050590  0.000000
#
#        ADSK       AEP      AMAT  ...       VLY      VRTX      WABC      WAFD  \
# 0 -0.011111 -0.021400 -0.001480  ... -0.037946  0.073214 -0.080537 -0.069620
# 1 -0.048689  0.011928 -0.049407  ... -0.051044 -0.079867 -0.017031 -0.023809
#
#         WBA      WERN      WSFS      WTFC       XEL      ZION
# 0 -0.023504 -0.031111 -0.029703 -0.032787 -0.025641 -0.062302
# 1 -0.037199 -0.002294 -0.030612  0.000000  0.023026 -0.048424
#
# [2 rows x 111 columns]

# %%
type(df["Date"])  #I check this because I cannot concatenate a timestamp data type below, so I decided to leave it as a series and then convert to date
# Out:
# pandas.core.series.Series

# %% [markdown]
# # 1 Testing Facebook Prophet Time Series Model

# %%
#Prophet is a univariate time series additive model. Therefore, we will need to forecast the returns of each stock one at a time,
#using the format specified by Facebook Prophet documentation:

ds = []
y = []

for i in range(0, 252):
  ds.append(df.Date.iloc[i])
  y.append(df.AAPL.iloc[i])

# %%
ds_df = pd.DataFrame(ds)
y_df = pd.DataFrame(y)
test_df = pd.concat([ds_df, y_df], axis= 1 )
test_df.columns = ["ds", "y"]
test_df["ds"] = pd.to_datetime(test_df["ds"])
test_df.tail(2)
# Out:
#             ds        y
# 250 2000-12-28  0.00000
# 251 2000-12-29  0.00422

# %%
m = Prophet()
m.fit(test_df)
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/4llubbst.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/sqqceewc.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=83599', 'data', 'file=/tmp/tmpu4lmilj9/4llubbst.json', 'init=/tmp/tmpu4lmilj9/sqqceewc.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_modelgjpah5b0/prophet_model-20240327102835.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:28:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:28:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
future = m.make_future_dataframe(periods = 252)  #We want to test how it forecasts returns approximately one year into the future
future        #It not only generates future dates but re-generates past dates and then adds 252 future dates. That's why our predictor below predicts in sample first.
# Out:
#             ds
# 0   2000-01-03
# 1   2000-01-04
# 2   2000-01-05
# 3   2000-01-06
# 4   2000-01-07
# ..         ...
# 499 2001-09-03
# 500 2001-09-04
# 501 2001-09-05
# 502 2001-09-06
# 503 2001-09-07
#
# [504 rows x 1 columns]

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].iloc[252:]  #It first produces an in_sample fit by default. Thus, we need iloc to find the actual...
                                                   #...forecasts out of sample. Yhat is the prediction, the others are the bounds of the confidence interval.
# Out:
#             ds      yhat  yhat_lower  yhat_upper
# 252 2000-12-30  0.035709   -0.029243    0.103679
# 253 2000-12-31  0.035658   -0.032970    0.099879
# 254 2001-01-01 -0.004401   -0.070132    0.065053
# 255 2001-01-02 -0.016597   -0.082811    0.056881
# 256 2001-01-03 -0.017023   -0.084933    0.053736
# ..         ...       ...         ...         ...
# 499 2001-09-03 -0.016986   -0.089381    0.057869
# 500 2001-09-04 -0.029181   -0.099226    0.037625
# 501 2001-09-05 -0.029607   -0.098868    0.039446
# 502 2001-09-06 -0.020570   -0.091457    0.050992
# 503 2001-09-07 -0.028750   -0.096601    0.040349
#
# [252 rows x 4 columns]

# %%
help(Prophet.make_future_dataframe) #I will try without including history
# Out:
# Help on function make_future_dataframe in module prophet.forecaster:
#
# make_future_dataframe(self, periods, freq='D', include_history=True)
#     Simulate the trend using the extrapolated generative model.
#
#     Parameters
#     ----------
#     periods: Int number of periods to forecast forward.
#     freq: Any valid frequency for pd.date_range, such as 'D' or 'M'.
#     include_history: Boolean to include the historical dates in the data
#         frame for predictions.
#
#     Returns
#     -------
#     pd.Dataframe that extends forward from the end of self.history for the
#     requested number of periods.

# %%
future = m.make_future_dataframe(periods = 365, include_history = False)  #We want to test how it forecasts returns approximately one year into the future
future   #Now it skips the in_sample dates
# Out:
#             ds
# 0   2000-12-30
# 1   2000-12-31
# 2   2001-01-01
# 3   2001-01-02
# 4   2001-01-03
# ..         ...
# 360 2001-12-25
# 361 2001-12-26
# 362 2001-12-27
# 363 2001-12-28
# 364 2001-12-29
#
# [365 rows x 1 columns]

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']]  #And now I don't need to use iloc
# Out:
#             ds      yhat  yhat_lower  yhat_upper
# 0   2000-12-30  0.035709   -0.037489    0.104870
# 1   2000-12-31  0.035658   -0.032219    0.104274
# 2   2001-01-01 -0.004401   -0.072310    0.068821
# 3   2001-01-02 -0.016597   -0.081368    0.049557
# 4   2001-01-03 -0.017023   -0.083500    0.050033
# ..         ...       ...         ...         ...
# 360 2001-12-25 -0.034934   -0.099031    0.033690
# 361 2001-12-26 -0.035360   -0.105559    0.032349
# 362 2001-12-27 -0.026323   -0.094576    0.035929
# 363 2001-12-28 -0.034502   -0.106426    0.031160
# 364 2001-12-29  0.017012   -0.051790    0.087827
#
# [365 rows x 4 columns]

# %%
forecast["yhat"].mean()
# Out:
# -0.007786967543508904

# %%
print(df.iloc[251])   #Yields the 29th december 2000
print(df.iloc[252])   #Yields the 2nd of February 2001
#We need to use 365 days for forecasting period with prophet instead of 252, because prophet uses 365 days a year, whereas our data has 252 days a year (only trading days)
# Out:
# Date    2000-12-29
# AAPL       0.00422
# ABCB      0.020408
# ACGL      0.043478
# ADBE     -0.055781
#            ...
# WERN           0.0
# WSFS      0.040404
# WTFC      0.011905
# XEL      -0.002146
# ZION      0.006042
# Name: 251, Length: 111, dtype: object
# Date    2001-01-02
# AAPL           0.0
# ABCB           0.0
# ACGL     -0.033333
# ADBE     -0.196652
#            ...
# WERN     -0.091912
# WSFS     -0.029126
# WTFC     -0.003922
# XEL      -0.025806
# ZION      -0.04004
# Name: 252, Length: 111, dtype: object

# %%
df.AAPL.iloc[251:499].mean() #Prediction is not the best. I use the mean because in mean_variance I need to specifiy the expected returns parameter
# Out:
# 0.0024413476322557998

# %%
#We will use more data this time, and try to find the best hyperparameters of the model
ds = []
y = []

for i in range(0, 1000):   #We changed the range to add more the data for the model
  ds.append(df.Date.iloc[i])
  y.append(df.AAPL.iloc[i])

# %%
ds_df = pd.DataFrame(ds)
y_df = pd.DataFrame(y)
test_df = pd.concat([ds_df, y_df], axis= 1 )
test_df.columns = ["ds", "y"]
test_df.tail(2)
# Out:
#              ds         y
# 998  2003-12-23 -0.002015
# 999  2003-12-24  0.030288

# %%
#HYPERPARAMETER TUNING
#Here we do cross-validation to assess prediction performance on a horizon of 252 days, starting with 700 days of
#training data in the first cutoff and then making predictions every 180 days
import itertools
from prophet.diagnostics import cross_validation, performance_metrics

#The hyperparameters we want to tune
param_grid = {
    'changepoint_prior_scale': [0.001, 0.01, 0.1, 0.5],
    'seasonality_prior_scale': [0.01, 0.1, 1.0, 10.0],
}

# Generate all combinations of parameters
all_params = [dict(zip(param_grid.keys(), v)) for v in itertools.product(*param_grid.values())]
rmses = []  # Store the RMSEs for each params here

# Use cross validation to evaluate all parameters
for params in all_params:
    m = Prophet(**params).fit(test_df)  # Fit model with given params
    df_cv = cross_validation(m, initial='730 days', period='180 days', horizon = '365 days', parallel="processes")  #Last one is parallelization method of cross validation
    df_p = performance_metrics(df_cv, rolling_window=1)
    rmses.append(df_p['rmse'].values[0])

# Find the best parameters
tuning_results = pd.DataFrame(all_params)
tuning_results['rmse'] = rmses
print(tuning_results)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/c0qxfelx.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/i5114_rs.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=32017', 'data', 'file=/tmp/tmpu4lmilj9/c0qxfelx.json', 'init=/tmp/tmpu4lmilj9/i5114_rs.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_model_h6ivop3/prophet_model-20240327102835.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:28:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:28:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Making 2 forecasts with cutoffs between 2002-06-27 00:00:00 and 2002-12-24 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x783b1cf396f0>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/9ff71f7u.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/fb8csg6y.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/v1etjwq1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/bd4f45oo.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=7516', 'data', 'file=/tmp/tmpu4lmilj9/9ff71f7u.json', 'init=/tmp/tmpu4lmilj9/bd4f45oo.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_modelmpj30qji/prophet_model-20240327102836.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=65604', 'data', 'file=/tmp/tmpu4lmilj9/fb8csg6y.json', 'init=/tmp/tmpu4lmilj9/v1etjwq1.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_modeltvahwirf/prophet_model-20240327102836.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:28:36 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:28:36 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:28:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 10:28:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Skipping MAPE because y close to 0
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/a7ggrbh2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/dz27x1nu.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=44384', 'data', 'file=/tmp/tmpu4lmilj9/a7ggrbh2.json', 'init=/tmp/tmpu4lmilj9/dz27x1nu.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_model2_lavj2a/prophet_model-20240327102837.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:28:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:28:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Making 2 forecasts with cutoffs between 2002-06-27 00:00:00 and 2002-12-24 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x783b1daa0580>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/n_4te7u4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/9r5c_2np.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/xc0zonud.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/zfsmasne.json
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=58700', 'data', 'file=/tmp/tmpu4lmilj9/9r5c_2np.json', 'init=/tmp/tmpu4lmilj9/xc0zonud.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_model3l6b9x8r/prophet_model-20240327102837.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# 10:28:37 - cmdstanpy - INFO - Chain [1] start processing
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=80503', 'data', 'file=/tmp/tmpu4lmilj9/n_4te7u4.json', 'init=/tmp/tmpu4lmilj9/zfsmasne.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_model0ruv_7py/prophet_model-20240327102837.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# INFO:cmdstanpy:Chain [1] start processing
# 10:28:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:28:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 10:28:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Skipping MAPE because y close to 0
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/ka4hkfgn.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/o2qmbvw5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=1206', 'data', 'file=/tmp/tmpu4lmilj9/ka4hkfgn.json', 'init=/tmp/tmpu4lmilj9/o2qmbvw5.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_modelvspxt_28/prophet_model-20240327102838.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:28:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:28:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Making 2 forecasts with cutoffs between 2002-06-27 00:00:00 and 2002-12-24 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x783b1cf39ff0>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/1gfq91jp.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/sevq1gmd.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/txn6uml4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=6306', 'data', 'file=/tmp/tmpu4lmilj9/1gfq91jp.json', 'init=/tmp/tmpu4lmilj9/txn6uml4.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_model8j1jzcr9/prophet_model-20240327102840.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:28:40 - cmdstanpy - INFO - Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/6dum8sgj.json
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=59785', 'data', 'file=/tmp/tmpu4lmilj9/sevq1gmd.json', 'init=/tmp/tmpu4lmilj9/6dum8sgj.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_model1ql5frxg/prophet_model-20240327102840.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:28:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:28:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 10:28:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Skipping MAPE because y close to 0
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/r6dgz354.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/3i3pmiy5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=1348', 'data', 'file=/tmp/tmpu4lmilj9/r6dgz354.json', 'init=/tmp/tmpu4lmilj9/3i3pmiy5.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_model2arej7l6/prophet_model-20240327102841.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:28:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:28:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Making 2 forecasts with cutoffs between 2002-06-27 00:00:00 and 2002-12-24 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x783b1cf3af80>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/r6zu1nyh.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/943aegl5.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/uhk2yrli.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/ghglamg7.json
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=80667', 'data', 'file=/tmp/tmpu4lmilj9/r6zu1nyh.json', 'init=/tmp/tmpu4lmilj9/uhk2yrli.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_modelr0u6cxkt/prophet_model-20240327102842.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:28:42 - cmdstanpy - INFO - Chain [1] start processing
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=10514', 'data', 'file=/tmp/tmpu4lmilj9/943aegl5.json', 'init=/tmp/tmpu4lmilj9/ghglamg7.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_modelhastl7xv/prophet_model-20240327102842.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:28:42 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:28:42 - cmdstanpy - INFO - Chain [1] done processing
# 10:28:42 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Skipping MAPE because y close to 0
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/z0fcsmy7.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/1fq35we8.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=69605', 'data', 'file=/tmp/tmpu4lmilj9/z0fcsmy7.json', 'init=/tmp/tmpu4lmilj9/1fq35we8.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_model0r4ydmiq/prophet_model-20240327102843.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:28:43 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:28:43 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Making 2 forecasts with cutoffs between 2002-06-27 00:00:00 and 2002-12-24 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x783b1c395990>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/zgao7lid.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/ylwot36j.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/d4oda9mt.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/p1viuse0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=57669', 'data', 'file=/tmp/tmpu4lmilj9/zgao7lid.json', 'init=/tmp/tmpu4lmilj9/p1viuse0.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_model0eduqgxg/prophet_model-20240327102843.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:28:43 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=86247', 'data', 'file=/tmp/tmpu4lmilj9/ylwot36j.json', 'init=/tmp/tmpu4lmilj9/d4oda9mt.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_model7oysxl6c/prophet_model-20240327102843.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:28:43 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:28:44 - cmdstanpy - INFO - Chain [1] done processing
# 10:28:44 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Skipping MAPE because y close to 0
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/vawejz4c.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/o4_su247.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=98618', 'data', 'file=/tmp/tmpu4lmilj9/vawejz4c.json', 'init=/tmp/tmpu4lmilj9/o4_su247.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_model07fi5d4u/prophet_model-20240327102845.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:28:45 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:28:45 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Making 2 forecasts with cutoffs between 2002-06-27 00:00:00 and 2002-12-24 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x783b1c52e350>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/tt4_uew7.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/_o4gpgho.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/ig9896kz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/rmk37k80.json
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=8288', 'data', 'file=/tmp/tmpu4lmilj9/tt4_uew7.json', 'init=/tmp/tmpu4lmilj9/ig9896kz.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_model8w5b40el/prophet_model-20240327102845.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:28:45 - cmdstanpy - INFO - Chain [1] start processing
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=45335', 'data', 'file=/tmp/tmpu4lmilj9/_o4gpgho.json', 'init=/tmp/tmpu4lmilj9/rmk37k80.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_modelgblwdi7x/prophet_model-20240327102845.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:28:45 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:28:45 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 10:28:45 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Skipping MAPE because y close to 0
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/3me96wol.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/4b03v3l2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=85559', 'data', 'file=/tmp/tmpu4lmilj9/3me96wol.json', 'init=/tmp/tmpu4lmilj9/4b03v3l2.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_modelw232zbum/prophet_model-20240327102846.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:28:46 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:28:46 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Making 2 forecasts with cutoffs between 2002-06-27 00:00:00 and 2002-12-24 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x783b1c52e920>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/n3lfip7v.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/ksmvxq6f.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/0xox7w3g.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=25555', 'data', 'file=/tmp/tmpu4lmilj9/n3lfip7v.json', 'init=/tmp/tmpu4lmilj9/0xox7w3g.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_modelmg7nt1z2/prophet_model-20240327102847.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:28:47 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:28:47 - cmdstanpy - INFO - Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/d5yu3be1.json
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=51405', 'data', 'file=/tmp/tmpu4lmilj9/ksmvxq6f.json', 'init=/tmp/tmpu4lmilj9/d5yu3be1.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_modelus5rw_vi/prophet_model-20240327102847.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:28:47 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:28:47 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Skipping MAPE because y close to 0
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/ozbm05yt.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/yjqkqs0g.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=53244', 'data', 'file=/tmp/tmpu4lmilj9/ozbm05yt.json', 'init=/tmp/tmpu4lmilj9/yjqkqs0g.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_model6w_7elfm/prophet_model-20240327102848.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:28:48 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:28:48 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Making 2 forecasts with cutoffs between 2002-06-27 00:00:00 and 2002-12-24 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x783b1cf3aaa0>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/7lqbffni.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/gflaijww.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/_5bcq54m.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=51695', 'data', 'file=/tmp/tmpu4lmilj9/7lqbffni.json', 'init=/tmp/tmpu4lmilj9/_5bcq54m.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_modelz3fleqjk/prophet_model-20240327102849.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:28:49 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/o8a4zd88.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=15267', 'data', 'file=/tmp/tmpu4lmilj9/gflaijww.json', 'init=/tmp/tmpu4lmilj9/o8a4zd88.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_modelb0363fgy/prophet_model-20240327102849.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:28:49 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:28:49 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 10:28:49 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Skipping MAPE because y close to 0
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/vwcghy_1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/i0tw5ny6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=74062', 'data', 'file=/tmp/tmpu4lmilj9/vwcghy_1.json', 'init=/tmp/tmpu4lmilj9/i0tw5ny6.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_modelf2en477v/prophet_model-20240327102850.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:28:50 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:28:50 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Making 2 forecasts with cutoffs between 2002-06-27 00:00:00 and 2002-12-24 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x783b1cf3af80>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/b6dhp84p.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/3ash0gpw.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/etbuzfzc.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=9809', 'data', 'file=/tmp/tmpu4lmilj9/b6dhp84p.json', 'init=/tmp/tmpu4lmilj9/etbuzfzc.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_modelsgdlx6z2/prophet_model-20240327102851.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:28:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/_7ygoy62.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=54013', 'data', 'file=/tmp/tmpu4lmilj9/3ash0gpw.json', 'init=/tmp/tmpu4lmilj9/_7ygoy62.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_model6_a_jax4/prophet_model-20240327102851.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:28:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:28:51 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 10:28:51 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Skipping MAPE because y close to 0
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/xvscwsfc.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/cg25vj4r.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=33320', 'data', 'file=/tmp/tmpu4lmilj9/xvscwsfc.json', 'init=/tmp/tmpu4lmilj9/cg25vj4r.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_modelig447dvj/prophet_model-20240327102853.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:28:53 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:28:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Making 2 forecasts with cutoffs between 2002-06-27 00:00:00 and 2002-12-24 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x783b1c396f50>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/2f6f05rr.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/trv5h6h6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/3xuuotvt.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=42847', 'data', 'file=/tmp/tmpu4lmilj9/2f6f05rr.json', 'init=/tmp/tmpu4lmilj9/3xuuotvt.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_modelcj21n4nw/prophet_model-20240327102854.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/3t8ac4un.json
# 10:28:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=30873', 'data', 'file=/tmp/tmpu4lmilj9/trv5h6h6.json', 'init=/tmp/tmpu4lmilj9/3t8ac4un.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_model5pxe5wtn/prophet_model-20240327102854.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:28:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:28:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 10:28:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Skipping MAPE because y close to 0
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/61k70zd9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/ddd31t40.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=2527', 'data', 'file=/tmp/tmpu4lmilj9/61k70zd9.json', 'init=/tmp/tmpu4lmilj9/ddd31t40.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_model5sszuj6g/prophet_model-20240327102856.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:28:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:28:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Making 2 forecasts with cutoffs between 2002-06-27 00:00:00 and 2002-12-24 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x783b1c4474f0>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/94cz9mu9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/v2o69no6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/6r7hl70k.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/gff_61uc.json
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=67253', 'data', 'file=/tmp/tmpu4lmilj9/v2o69no6.json', 'init=/tmp/tmpu4lmilj9/6r7hl70k.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_model87v2k_v7/prophet_model-20240327102856.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# DEBUG:cmdstanpy:idx 0
# 10:28:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=70152', 'data', 'file=/tmp/tmpu4lmilj9/94cz9mu9.json', 'init=/tmp/tmpu4lmilj9/gff_61uc.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_modelu8x4e85v/prophet_model-20240327102856.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:28:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:28:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 10:28:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Skipping MAPE because y close to 0
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/ndwlz95r.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/we5c_ztl.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=87299', 'data', 'file=/tmp/tmpu4lmilj9/ndwlz95r.json', 'init=/tmp/tmpu4lmilj9/we5c_ztl.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_modelf7ail09n/prophet_model-20240327102857.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:28:57 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:28:57 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Making 2 forecasts with cutoffs between 2002-06-27 00:00:00 and 2002-12-24 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x783b1c402830>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/6b9fgygv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/24eaqkd1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/6flano5b.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/5l38m1ng.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=2505', 'data', 'file=/tmp/tmpu4lmilj9/6b9fgygv.json', 'init=/tmp/tmpu4lmilj9/6flano5b.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_modelzobni7bn/prophet_model-20240327102858.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:28:58 - cmdstanpy - INFO - Chain [1] start processing
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=17932', 'data', 'file=/tmp/tmpu4lmilj9/24eaqkd1.json', 'init=/tmp/tmpu4lmilj9/5l38m1ng.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_model725fkeje/prophet_model-20240327102858.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# INFO:cmdstanpy:Chain [1] start processing
# 10:28:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:28:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 10:28:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Skipping MAPE because y close to 0
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/3eopnq5k.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/l56lprft.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=19766', 'data', 'file=/tmp/tmpu4lmilj9/3eopnq5k.json', 'init=/tmp/tmpu4lmilj9/l56lprft.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_model5fh9ycup/prophet_model-20240327102859.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:28:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:28:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Making 2 forecasts with cutoffs between 2002-06-27 00:00:00 and 2002-12-24 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x783b1c52fd00>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/il8jaypr.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/l0az6wsi.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/r2wg4mk0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=55108', 'data', 'file=/tmp/tmpu4lmilj9/il8jaypr.json', 'init=/tmp/tmpu4lmilj9/r2wg4mk0.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_modeljcm6vva0/prophet_model-20240327102900.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:29:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/0hyu2vca.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=26415', 'data', 'file=/tmp/tmpu4lmilj9/l0az6wsi.json', 'init=/tmp/tmpu4lmilj9/0hyu2vca.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_modellljzvyue/prophet_model-20240327102900.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:29:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:29:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 10:29:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Skipping MAPE because y close to 0
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/x532osxv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/2riuz2fo.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=59980', 'data', 'file=/tmp/tmpu4lmilj9/x532osxv.json', 'init=/tmp/tmpu4lmilj9/2riuz2fo.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_modelt2t0xqce/prophet_model-20240327102901.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:29:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:29:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Making 2 forecasts with cutoffs between 2002-06-27 00:00:00 and 2002-12-24 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x783b1cf38400>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/nws9_isd.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/mrasu3rk.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/rgenvmkr.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=97750', 'data', 'file=/tmp/tmpu4lmilj9/nws9_isd.json', 'init=/tmp/tmpu4lmilj9/rgenvmkr.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_modelesu4pkct/prophet_model-20240327102902.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:29:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/t65j3ti9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=35697', 'data', 'file=/tmp/tmpu4lmilj9/mrasu3rk.json', 'init=/tmp/tmpu4lmilj9/t65j3ti9.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_modelbt5dp3dk/prophet_model-20240327102902.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:29:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:29:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 10:29:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Skipping MAPE because y close to 0
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/8_jr858z.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/4ut3tid5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=3195', 'data', 'file=/tmp/tmpu4lmilj9/8_jr858z.json', 'init=/tmp/tmpu4lmilj9/4ut3tid5.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_modelhosb5dhw/prophet_model-20240327102903.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:29:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:29:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Making 2 forecasts with cutoffs between 2002-06-27 00:00:00 and 2002-12-24 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x783b1c397970>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/m1ci85yk.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/fynjsfli.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/_773pvw0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=26485', 'data', 'file=/tmp/tmpu4lmilj9/fynjsfli.json', 'init=/tmp/tmpu4lmilj9/_773pvw0.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_modelwvxu4psl/prophet_model-20240327102904.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:29:04 - cmdstanpy - INFO - Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/c_hm3ba6.json
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=62668', 'data', 'file=/tmp/tmpu4lmilj9/m1ci85yk.json', 'init=/tmp/tmpu4lmilj9/c_hm3ba6.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_modelno9u6llm/prophet_model-20240327102904.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:29:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:29:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 10:29:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Skipping MAPE because y close to 0
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/su6mpwfw.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/p1415d48.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=60717', 'data', 'file=/tmp/tmpu4lmilj9/su6mpwfw.json', 'init=/tmp/tmpu4lmilj9/p1415d48.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_modelbgq56u3z/prophet_model-20240327102905.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:29:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:29:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Making 2 forecasts with cutoffs between 2002-06-27 00:00:00 and 2002-12-24 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x783b1c4004f0>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/_mgbe208.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/rh47g1dg.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/qlu970mt.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=17343', 'data', 'file=/tmp/tmpu4lmilj9/_mgbe208.json', 'init=/tmp/tmpu4lmilj9/qlu970mt.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_model7lc1tahj/prophet_model-20240327102906.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:29:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpu4lmilj9/uhl6gd75.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=49316', 'data', 'file=/tmp/tmpu4lmilj9/rh47g1dg.json', 'init=/tmp/tmpu4lmilj9/uhl6gd75.json', 'output', 'file=/tmp/tmpu4lmilj9/prophet_modelv4iqcysa/prophet_model-20240327102906.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:29:07 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:29:07 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 10:29:07 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Skipping MAPE because y close to 0
#     changepoint_prior_scale  seasonality_prior_scale      rmse
# 0                     0.001                     0.01  0.034169
# 1                     0.001                     0.10  0.033967
# 2                     0.001                     1.00  0.033071
# 3                     0.001                    10.00  0.034112
# 4                     0.010                     0.01  0.025731
# 5                     0.010                     0.10  0.026197
# 6                     0.010                     1.00  0.026206
# 7                     0.010                    10.00  0.026197
# 8                     0.100                     0.01  0.026714
# 9                     0.100                     0.10  0.027182
# 10                    0.100                     1.00  0.027387
# 11                    0.100                    10.00  0.027504
# 12                    0.500                     0.01  0.029695
# 13                    0.500                     0.10  0.030782
# 14                    0.500                     1.00  0.030869
# 15                    0.500                    10.00  0.030608

# %%
best_params = all_params[np.argmin(rmses)]
print(best_params)    #Judged Based on the Root-Mean_Square-Error metric, suggested by the Prophet documentation
# Out:
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.01}

# %% [markdown]
# # 2 Testing Garch Volatility Model

# %% [markdown]
# The GARCH Model needs two parameters to be defined. The number of lagged variances (p) that we will consider when running the model, and the number of lagged residual errors (q). The first one can be determined with by calculating the autocorrelation of the data of returns, and the second one by calculating the partial autocorrelation of the same data.

# %%
# !pip install arch
# Out:
# Collecting arch
#   Downloading arch-6.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (982 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.0/983.0 kB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.19 in /usr/local/lib/python3.10/dist-packages (from arch) (1.25.2)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.10/dist-packages (from arch) (1.11.4)
# Requirement already satisfied: pandas>=1.1 in /usr/local/lib/python3.10/dist-packages (from arch) (1.5.3)
# Requirement already satisfied: statsmodels>=0.12 in /usr/local/lib/python3.10/dist-packages (from arch) (0.14.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1->arch) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1->arch) (2023.4)
# Requirement already satisfied: patsy>=0.5.4 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.12->arch) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.12->arch) (24.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.4->statsmodels>=0.12->arch) (1.16.0)
# Installing collected packages: arch
# Successfully installed arch-6.3.0

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from arch import arch_model

# %%
aapl_data = [df.AAPL.iloc[i] for i in range(0, 252)]
aapl_data = pd.Series(aapl_data)

mean = aapl_data.mean()

squared_data = [(i - mean)**2 for i in aapl_data]   #We do this to plot the autocorrelation and partial autocorrelation plots
squared_data = pd.Series(squared_data)
len(squared_data)
# Out:
# 252

# %%
#Create Autocorrelation Function Plot. The blue area represents the confidence interval
plot_acf(squared_data)
plt.plot() #Since there is few to no autocorrelation, we choose p = 1. We assume that there most be some autocorrelation,
            # because research shows variance does have some autocorrelation, but we could not find a lot here, so we only use one lag
# Out:
# []

# %%
#Create Partial Autocorrelation Function Plot. The blue area represents the confidence interval
plot_pacf(squared_data)
plt.plot()  #Again, we will choose q = 1
# Out:
# []

# %%
help(arch_model)  #We will use a vol = GARCH, mean = "Constant" (I have seen many examples where they assume this),
                      #p = 1, q = 1, and default error distribution (gaussian)
# Out:
# Help on function arch_model in module arch.univariate.mean:
#
# arch_model(y: 'ArrayLike | None', x: 'ArrayLike2D | None' = None, mean: "Literal['Constant', 'Zero', 'LS', 'AR', 'ARX', 'HAR', 'HARX', 'constant', 'zero']" = 'Constant', lags: 'None | int | list[int] | Int32Array | Int64Array' = 0, vol: "Literal['GARCH', 'ARCH', 'EGARCH', 'FIGARCH', 'APARCH', 'HARCH', 'FIGARCH']" = 'GARCH', p: 'int | list[int]' = 1, o: 'int' = 0, q: 'int' = 1, power: 'float' = 2.0, dist: "Literal['normal', 'gaussian', 't', 'studentst', 'skewstudent', 'skewt', 'ged', 'generalized error']" = 'normal', hold_back: 'int | None' = None, rescale: 'bool | None' = None) -> 'HARX'
#     Initialization of common ARCH model specifications
#
#     Parameters
#     ----------
#     y : ndarray, Series, None
#         The dependent variable
#     x : ndarray, DataFrame, optional
#         Exogenous regressors.  Ignored if model does not permit exogenous
#         regressors.
#     mean : str, optional
#         Name of the mean model.  Currently supported options are: 'Constant',
#         'Zero', 'LS', 'AR', 'ARX', 'HAR' and  'HARX'
#     lags : int or list[int], optional
#         Either a scalar integer value indicating lag length or a list of
#         integers specifying lag locations.
#     vol : str, optional
#         Name of the volatility model.  Currently supported options are:
#         'GARCH' (default), 'ARCH', 'EGARCH', 'FIGARCH', 'APARCH' and 'HARCH'
#     p : int, optional
#         Lag order of the symmetric innovation
#     o : int, optional
#         Lag order of the asymmetric innovation
#     q : int, optional
#         Lag order of lagged volatility or equivalent
#     power : float, optional
#         Power to use with GARCH and related models
#     dist : int, optional
#         Name of the error distribution.  Currently supported options are:
#
#             * Normal: 'normal', 'gaussian' (default)
#             * Students's t: 't', 'studentst'
#             * Skewed Student's t: 'skewstudent', 'skewt'
#             * Generalized Error Distribution: 'ged', 'generalized error"
#
#     hold_back : int
#         Number of observations at the start of the sample to exclude when
#         estimating model parameters.  Used when comparing models with different
#         lag lengths to estimate on the common sample.
#     rescale : bool
#         Flag indicating whether to automatically rescale data if the scale
#         of the data is likely to produce convergence issues when estimating
#         model parameters. If False, the model is estimated on the data without
#         transformation.  If True, than y is rescaled and the new scale is
#         reported in the estimation results.
#
#     Returns
#     -------
#     model : ARCHModel
#         Configured ARCH model
#
#     Examples
#     --------
#     >>> import datetime as dt
#     >>> import pandas_datareader.data as web
#     >>> djia = web.get_data_fred('DJIA')
#     >>> returns = 100 * djia['DJIA'].pct_change().dropna()
#
#     A basic GARCH(1,1) with a constant mean can be constructed using only
#     the return data
#
#     >>> from arch.univariate import arch_model
#     >>> am = arch_model(returns)
#
#     Alternative mean and volatility processes can be directly specified
#
#     >>> am = arch_model(returns, mean='AR', lags=2, vol='harch', p=[1, 5, 22])
#
#     This example demonstrates the construction of a zero mean process
#     with a TARCH volatility process and Student t error distribution
#
#     >>> am = arch_model(returns, mean='zero', p=1, o=1, q=1,
#     ...                 power=1.0, dist='StudentsT')
#
#     Notes
#     -----
#     Input that are not relevant for a particular specification, such as `lags`
#     when `mean='zero'`, are silently ignored.

# %%
m = arch_model(aapl_data, mean = "Constant", vol = "GARCH", p = 1, q = 1)
res = m.fit()
# Out:
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 2057264.0147079309
# Iteration:      2,   Func. Count:     16,   Neg. LLF: 280.15688207395107
# Iteration:      3,   Func. Count:     22,   Neg. LLF: -358.78536395277627
# Iteration:      4,   Func. Count:     29,   Neg. LLF: 2328.21045909441
# Iteration:      5,   Func. Count:     35,   Neg. LLF: -388.0272129706391
# Iteration:      6,   Func. Count:     42,   Neg. LLF: 104140.00615877676
# Iteration:      7,   Func. Count:     48,   Neg. LLF: -396.73719020076936
# Iteration:      8,   Func. Count:     53,   Neg. LLF: -229.46753185958283
# Iteration:      9,   Func. Count:     60,   Neg. LLF: -396.3026322629173
# Iteration:     10,   Func. Count:     66,   Neg. LLF: -396.82571816977014
# Iteration:     11,   Func. Count:     71,   Neg. LLF: -396.82930363197113
# Iteration:     12,   Func. Count:     76,   Neg. LLF: -396.8293115702533
# Iteration:     13,   Func. Count:     80,   Neg. LLF: -396.8293115699996
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -396.8293115702533
#             Iterations: 13
#             Function evaluations: 80
#             Gradient evaluations: 13
# /usr/local/lib/python3.10/dist-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.003028. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(

# %%
f = res.forecast(horizon = 252)
f.variance.values
# Out:
# array([[0.00159026, 0.00251847, 0.00309773, 0.00345923, 0.00368482,
#         0.00382561, 0.00391346, 0.00396829, 0.00400251, 0.00402386,
#         0.00403719, 0.00404551, 0.00405069, 0.00405393, 0.00405595,
#         0.00405722, 0.004058  , 0.00405849, 0.0040588 , 0.00405899,
#         0.00405911, 0.00405919, 0.00405923, 0.00405926, 0.00405928,
#         0.00405929, 0.0040593 , 0.0040593 , 0.00405931, 0.00405931,
#         0.00405931, 0.00405931, 0.00405931, 0.00405931, 0.00405931,
#         0.00405931, 0.00405931, 0.00405931, 0.00405931, 0.00405931,
#         0.00405931, 0.00405931, 0.00405931, 0.00405931, 0.00405931,
#         0.00405931, 0.00405931, 0.00405931, 0.00405931, 0.00405931,
#         0.00405931, 0.00405931, 0.00405931, 0.00405931, 0.00405931,
#         0.00405931, 0.00405931, 0.00405931, 0.00405931, 0.00405931,
#         0.00405931, 0.00405931, 0.00405931, 0.00405931, 0.00405931,
#         0.00405931, 0.00405931, 0.00405931, 0.00405931, 0.00405931,
#         0.00405931, 0.00405931, 0.00405931, 0.00405931, 0.00405931,
#         0.00405931, 0.00405931, 0.00405931, 0.00405931, 0.00405931,
#         0.00405931, 0.00405931, 0.00405931, 0.00405931, 0.00405931,
#         0.00405931, 0.00405931, 0.00405931, 0.00405931, 0.00405931,
#         0.00405931, 0.00405931, 0.00405931, 0.00405931, 0.00405931,
#         0.00405931, 0.00405931, 0.00405931, 0.00405931, 0.00405931,
#         0.00405931, 0.00405931, 0.00405931, 0.00405931, 0.00405931,
#         0.00405931, 0.00405931, 0.00405931, 0.00405931, 0.00405931,
#         0.00405931, 0.00405931, 0.00405931, 0.00405931, 0.00405931,
#         0.00405931, 0.00405931, 0.00405931, 0.00405931, 0.00405931,
#         0.00405931, 0.00405931, 0.00405931, 0.00405931, 0.00405931,
#         0.00405931, 0.00405931, 0.00405931, 0.00405931, 0.00405931,
#         0.00405931, 0.00405931, 0.00405931, 0.00405931, 0.00405931,
#         0.00405931, 0.00405931, 0.00405931, 0.00405931, 0.00405931,
#         0.00405931, 0.00405931, 0.00405931, 0.00405931, 0.00405931,
#         0.00405931, 0.00405931, 0.00405931, 0.00405931, 0.00405931,
#         0.00405931, 0.00405931, 0.00405931, 0.00405931, 0.00405931,
#         0.00405931, 0.00405931, 0.00405931, 0.00405931, 0.00405931,
#         0.00405931, 0.00405931, 0.00405931, 0.00405931, 0.00405931,
#         0.00405931, 0.00405931, 0.00405931, 0.00405931, 0.00405931,
#         0.00405931, 0.00405931, 0.00405931, 0.00405931, 0.00405931,
#         0.00405931, 0.00405931, 0.00405931, 0.00405931, 0.00405931,
#         0.00405931, 0.00405931, 0.00405931, 0.00405931, 0.00405931,
#         0.00405931, 0.00405931, 0.00405931, 0.00405931, 0.00405931,
#         0.00405931, 0.00405931, 0.00405931, 0.00405931, 0.00405931,
#         0.00405931, 0.00405931, 0.00405931, 0.00405931, 0.00405931,
#         0.00405931, 0.00405931, 0.00405931, 0.00405931, 0.00405931,
#         0.00405931, 0.00405931, 0.00405931, 0.00405931, 0.00405931,
#         0.00405931, 0.00405931, 0.00405931, 0.00405931, 0.00405931,
#         0.00405931, 0.00405931, 0.00405931, 0.00405931, 0.00405931,
#         0.00405931, 0.00405931, 0.00405931, 0.00405931, 0.00405931,
#         0.00405931, 0.00405931, 0.00405931, 0.00405931, 0.00405931,
#         0.00405931, 0.00405931, 0.00405931, 0.00405931, 0.00405931,
#         0.00405931, 0.00405931, 0.00405931, 0.00405931, 0.00405931,
#         0.00405931, 0.00405931, 0.00405931, 0.00405931, 0.00405931,
#         0.00405931, 0.00405931, 0.00405931, 0.00405931, 0.00405931,
#         0.00405931, 0.00405931]])

# %% [markdown]
# # 3 Backtesting Mean-Variance Models with Time Series Forecasting

# %%
#This code snippet creates a class to suppress unnecessary output from Prophet
import os
import sys
import logging

# from https://stackoverflow.com/questions/11130156/suppress-stdout-stderr-print-from-python-functions
class suppress_stdout_stderr(object):
    '''
    A context manager for doing a "deep suppression" of stdout and stderr in
    Python, i.e. will suppress all print, even if the print originates in a
    compiled C/Fortran sub-function.
       This will not suppress raised exceptions, since exceptions are printed
    to stderr just before a script exits, and after the context manager has
    exited (at least, I think that is why it lets exceptions through).

    '''
    def __init__(self):
        # Open a pair of null files
        self.null_fds = [os.open(os.devnull, os.O_RDWR) for x in range(2)]
        # Save the actual stdout (1) and stderr (2) file descriptors.
        self.save_fds = (os.dup(1), os.dup(2))

    def __enter__(self):
        # Assign the null pointers to stdout and stderr.
        os.dup2(self.null_fds[0], 1)
        os.dup2(self.null_fds[1], 2)

    def __exit__(self, *_):
        # Re-assign the real stdout/stderr back to (1) and (2)
        os.dup2(self.save_fds[0], 1)
        os.dup2(self.save_fds[1], 2)
        # Close the null files
        os.close(self.null_fds[0])
        os.close(self.null_fds[1])

logging.getLogger("cmdstanpy").setLevel(logging.WARNING)

# %%
# Function to forecast returns using Facebook Prophet
def forecast_returns(returns_data):
    forecasted_returns_means = []
    for col in returns_data.columns[1:]:  # Exclude the date column
        # Prepare data for Prophet
        df = returns_data[['Date', col]].copy()
        df.columns = ['ds', 'y']
        df["ds"] = pd.to_datetime(df["ds"])

        # Create and fit Prophet model
        model = Prophet(daily_seasonality=False, yearly_seasonality= True, changepoint_prior_scale= 0.01, seasonality_prior_scale= 0.01 )
        with suppress_stdout_stderr():
          model.fit(df)

        # Make future dataframe for one year ahead
        future = model.make_future_dataframe(periods=365, include_history = False)

        # Forecast returns
        forecast = model.predict(future)

        # Extract forecasted returns for the next year
        forecast_next_year = forecast['yhat'].values

        # Calculate mean of forecasted returns
        forecasted_return_mean = forecast_next_year.mean()
        forecasted_returns_means.append(forecasted_return_mean)

    # Convert list to array
    forecasted_returns_means = np.array(forecasted_returns_means)

    # Annualize forecasted returns means
    annualized_forecasted_returns_means = np.power(1 + forecasted_returns_means, 252) - 1

    return annualized_forecasted_returns_means


# Function to forecast volatility using GARCH model
def forecast_volatility(returns_data):
    vol_forecasts = []
    for col in returns_data.columns[1:]:
        # Fit GARCH model
        model = arch_model(returns_data[col], mean = "Constant", vol = "GARCH", p = 1, q = 1, rescale= False)
        result = model.fit(disp='off')

        # Forecast one year ahead
        forecasts = result.forecast(horizon=252)

        # Calculate forecasted volatility for the next year (model returns variance, not std)
        forecasted_volatility_next_year = np.sqrt(forecasts.variance.values[-1])

        vol_forecasts.append(forecasted_volatility_next_year)

    # Convert list to array
    vol_forecasts = np.array(vol_forecasts)

    return vol_forecasts


# Function to forecast correlation matrix using rolling window
def forecast_correlation_matrix(returns_data):
    rolling_corr = returns_data.rolling(window=252).corr(numeric_only= True)

    # Extract correlation matrix for the last day of the year
    correlation_matrix_next_year = rolling_corr.iloc[-110:]

    return correlation_matrix_next_year

# %%
#Functions used before for the Classical Mean Variance backtesting

def portfolio_gross_return (r, w):
  "Expected return of the portfolio is the weighted average of returns of the assets composing it. Not adjusted for costs. Return as % of capital invested"

  if type(r) == type(df.iloc[1]):
    #We need to remove the date column
    r = r.drop(["Date"])
  else:
    pass
  #r represents the returns of each asset
  #w represents the weights that go to each asset

  return np.dot(r, w)

def portfolio_volatility (w, covar):
  "Portfolio volatility is the following matrix multiplication: w^T . covariance_matrix . w"
  return np.sqrt(np.dot(w.T, np.dot(covar, w)))

def adjusted_port_return (portfolio_gross_return, initial_weights,  desired_weights, transaction_rate):
  "Desired weights are those obtained from the optimization. Transaction rate represents the % of transactions (change in weights) that represent costs"
  #We think of transaction costs calculation as a % of returns derived from the rate of weight changes that represent costs
  # % adjusted return = % gross return - % transaction cost
  #                 = % gross return - (sum(transaction_rate * weight changes))
  # Recall that because we used the .pct_change() pandas function to calculate returns, all returns are percentage returns

  vector_transaction_costs = transaction_rate * np.abs(initial_weights - desired_weights)
  total_transaction_costs = np.sum(vector_transaction_costs)
  adjusted_return = portfolio_gross_return - total_transaction_costs

  return adjusted_return

#MVP Optimization Model
def minimum_variance_portfolio (covariance_matrix, initial_weights):
  "This optimization method will find the highest return possible that one can get with the minimum risk: we will minimize the portfolio volatility"
  num_assets = len(initial_weights)

  #Set the weight constraints: all of them should be between 0 and 1 because we are working with a no-short strategy
  bounds = Bounds(0, 1)

  #Sum of weights should also equal 1 (100% of our capital)
  constraint_matrix = np.ones((1, num_assets))
  linear_constraint = LinearConstraint(constraint_matrix, [1], [1])

  #Calculate portfolio volatility (but we do this because the function "minimize" needs a function as input in the first argument, not a function call)
  def port_vol (initial_weights, covariance_matrix):
    port_vol = portfolio_volatility(initial_weights, covariance_matrix)
    return port_vol

  result = minimize(port_vol, initial_weights, args = (covariance_matrix), method = "trust-constr", constraints = linear_constraint, bounds = bounds)

  return result

  #Max Sharpe Ratio Optimization Model
def neg_sharpe_ratio(weights, covar_matrix, expected_returns):
  portfolio_vol = portfolio_volatility(weights, covar_matrix)
  portfolio_ret = portfolio_gross_return(expected_returns, weights)
  return -portfolio_ret / portfolio_vol  # negative value for minimization

def sharpe_ratio_max (weights, covar_matrix, expected_returns):

  num_stocks = len(weights)

  # All weights must be between 0 and 1, so set 0 and 1 as the boundaries.
  bounds = Bounds(0, 1)

  # Set the constraint that the sum of weights equals 1.
  constraint_matrix = np.ones((1, num_stocks))
  linear_constraint = LinearConstraint(constraint_matrix, [1], [1])

  def neg_sh (weights, covar_matrix, expected_returns):
    sh = neg_sharpe_ratio(weights, covar_matrix, expected_returns)
    return sh

  # Minimize the negative Sharpe ratio (to maximize Sharpe ratio) using 'trust-constr' method with constraints and bounds.
  res_sharpe = minimize(neg_sh, weights, args = (covar_matrix, expected_returns), method='trust-constr', constraints=linear_constraint, bounds=bounds)

  return res_sharpe

# %% [markdown]
# ## 3.1 Backtesting with Max Sharpe Ratio Strategy

# %%
# Function to backtest the Max-Sharpe optimization strategy with annual rebalancing
def backtest_Max_Sharpe_strategy(returns, transaction_cost_rate):
    num_assets = len(returns.columns[1:])       #Returns meaning our daily return data: our dataframe
    num_days = len(returns)
    rebalancing_period = 252  # Number of trading days in a year
    investing_capital = 10000   #The capital to be used with this strategy
    initial_transaction_cost = np.sum(np.dot(np.ones(num_assets), 1/num_assets)) * transaction_cost_rate #Initial transaction cost (in %) resulting from buying the equally weighted portfolio (from 0 weighting to 1/n)
    initial_portfolio_value = investing_capital - initial_transaction_cost * investing_capital  #The amount we would invest, adjusted for initial cost. And we will see how it evolves over time
    portfolio_value = initial_portfolio_value
    portfolio_values = [initial_portfolio_value]
    adjusted_returns = []
    portfolio_volatilities = []
    previous_weights = np.ones(num_assets) / num_assets  # Initial equally weighted portfolio

    for day in range(num_days):
        if day % rebalancing_period == 0 and day > 756:     #I will start rebalancing at the end of the 4th year (day 1008), because the models need a large amount of data before the present good performance. Otherwise, I am losing computational efficiency without really having good predictions.

            # Forecast returns for the next year
            annualized_forecast_next_year = forecast_returns(returns.iloc[:day])

            # Forecast volatility for the next year
            forecasted_volatility_next_year = forecast_volatility(returns.iloc[:day])

            # Forecast correlation matrix for the next year
            correlation_matrix_next_year = forecast_correlation_matrix(returns.iloc[:day])

            # Calculate covariance matrix using the forecasted volatility and correlation matrix
            forecasted_covariance_matrix_next_year = np.matmul(np.matmul(np.diag(forecasted_volatility_next_year), correlation_matrix_next_year), np.diag(forecasted_volatility_next_year).T)
            forecasted_covariance_matrix_next_year = forecasted_covariance_matrix_next_year * 252    #Simple Annualizing method

            # Calculate Max Sharpe portfolio
            Max_Sharpe = sharpe_ratio_max(previous_weights, forecasted_covariance_matrix_next_year, annualized_forecast_next_year)
            weights = Max_Sharpe.x

            # Calculate portfolio returns (daily)
            portfolio_return = portfolio_gross_return(returns.iloc[day], weights)

            # Adjust returns for transaction costs
            adjusted_return = adjusted_port_return(portfolio_return, previous_weights, weights, transaction_cost_rate )

            # Store adjusted returns
            adjusted_returns.append(adjusted_return)

            # Update portfolio value
            portfolio_value = portfolio_values[-1] * (1 + adjusted_return)

            # Store portfolio value
            portfolio_values.append(portfolio_value)

            # Recalculate portfolio volatility (daily) and store value
            covariance_matrix = returns.iloc[:day].cov(numeric_only = True)
            portfolio_volatility_value = portfolio_volatility(weights, covariance_matrix)
            portfolio_volatilities.append(portfolio_volatility_value)

            #In the next period, optimized weights in this period will be the previous weights
            previous_weights = weights
        else:
            # Calculate portfolio returns(daily)
            portfolio_return = portfolio_gross_return(returns.iloc[day], previous_weights)

            #If there is no rebalancing, there are no transaction costs for this period
            adjusted_return = portfolio_return

            # Store adjusted returns
            adjusted_returns.append(adjusted_return)

            # Update portfolio value
            portfolio_value = portfolio_values[-1] * (1 + adjusted_return)

            # Store portfolio value
            portfolio_values.append(portfolio_value)

            #Calculate the covariance up to this point, to track volatility (even if we do not rebalance we calculate volatility)
            covar_data = returns.iloc[:day]
            covar_matrix = covar_data.cov(numeric_only = True)

            # Recalculate portfolio volatility (daily) and store value
            portfolio_volatility_value = portfolio_volatility(previous_weights, covar_matrix)
            portfolio_volatilities.append(portfolio_volatility_value)

    return portfolio_values, adjusted_returns, portfolio_volatilities

# %%
transaction_rate = 0.01

Max_shp_portfolio_values, Max_shp_adjusted_returns, Max_shp_portfolio_volatilities = backtest_Max_Sharpe_strategy(df, transaction_rate)
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:520: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:121: RuntimeWarning: divide by zero encountered in divide
#   ret = um.true_divide(
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:121: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py:10474: RuntimeWarning: Degrees of freedom <= 0 for slice
#   base_cov = np.cov(mat.T, ddof=ddof)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2748: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2748: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py:10474: RuntimeWarning: Degrees of freedom <= 0 for slice
#   base_cov = np.cov(mat.T, ddof=ddof)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2748: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2748: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)

# %%
Maxsharpe_returns_and_vol = pd.DataFrame({"Max Shp Portfolio Returns": Max_shp_adjusted_returns, "Max Shp Volatility": Max_shp_portfolio_volatilities })
Maxsharpe_returns_and_vol = Maxsharpe_returns_and_vol.dropna()
len(Maxsharpe_returns_and_vol)
# Out:
# 5092

# %%
Maxsharpe_returns_and_vol["Rolling Sharpe Ratio"] = np.sqrt(252)* (Maxsharpe_returns_and_vol["Max Shp Portfolio Returns"].rolling(252).mean() / Maxsharpe_returns_and_vol["Max Shp Volatility"].rolling(252).mean())
Maxsharpe_returns_and_vol
# Out:
#       Max Shp Portfolio Returns  Max Shp Volatility  Rolling Sharpe Ratio
# 2                      0.007721            0.011441                   NaN
# 3                     -0.006257            0.019683                   NaN
# 4                      0.020144            0.016421                   NaN
# 5                      0.016604            0.020004                   NaN
# 6                     -0.016055            0.019952                   NaN
# ...                         ...                 ...                   ...
# 5089                   0.063983            0.015317              0.293435
# 5090                  -0.037692            0.015341              0.106673
# 5091                   0.032131            0.015349              0.218872
# 5092                  -0.013506            0.015353              0.079108
# 5093                  -0.051529            0.015353             -0.142684
#
# [5092 rows x 3 columns]

# %% [markdown]
# ## 3.2 Backtesting with MVP Strategy

# %%
# Function to backtest the Max-Sharpe optimization strategy with annual rebalancing
def backtest_MVP_strategy(returns, transaction_cost_rate):
    num_assets = len(returns.columns[1:])       #Returns meaning our daily return data: our dataframe
    num_days = len(returns)
    rebalancing_period = 252  # Number of trading days in a year
    investing_capital = 10000   #The capital to be used with this strategy
    initial_transaction_cost = np.sum(np.dot(np.ones(num_assets), 1/num_assets)) * transaction_cost_rate #Initial transaction cost (in %) resulting from buying the equally weighted portfolio (from 0 weighting to 1/n)
    initial_portfolio_value = investing_capital - initial_transaction_cost * investing_capital  #The amount we would invest, adjusted for initial cost. And we will see how it evolves over time
    portfolio_value = initial_portfolio_value
    portfolio_values = [initial_portfolio_value]
    adjusted_returns = []
    portfolio_volatilities = []
    previous_weights = np.ones(num_assets) / num_assets  # Initial equally weighted portfolio

    for day in range(num_days):
        if day % rebalancing_period == 0 and day > 756:     #I will start rebalancing after the end of the 4th year (day 1008), because the models need a large amount of data before the present good performance. Otherwise, I am losing computational efficiency without really having good predictions.

            # Forecast volatility for the next year (I only need to forecast volatility for the MVP Strategy)
            forecasted_volatility_next_year = forecast_volatility(returns.iloc[:day])

            # Forecast correlation matrix for the next year
            correlation_matrix_next_year = forecast_correlation_matrix(returns.iloc[:day])

            # Calculate covariance matrix using the forecasted volatility and correlation matrix
            forecasted_covariance_matrix_next_year = np.matmul(np.matmul(np.diag(forecasted_volatility_next_year), correlation_matrix_next_year), np.diag(forecasted_volatility_next_year).T)
            forecasted_covariance_matrix_next_year = forecasted_covariance_matrix_next_year * 252    #Simple Annualizing method

            # Calculate Max Sharpe portfolio
            MVP = minimum_variance_portfolio(forecasted_covariance_matrix_next_year, previous_weights)
            weights = MVP.x

            # Calculate portfolio returns (daily)
            portfolio_return = portfolio_gross_return(returns.iloc[day], weights)

            # Adjust returns for transaction costs
            adjusted_return = adjusted_port_return(portfolio_return, previous_weights, weights, transaction_cost_rate )

            # Store adjusted returns
            adjusted_returns.append(adjusted_return)

            # Update portfolio value
            portfolio_value = portfolio_values[-1] *(1 + adjusted_return)

            # Store portfolio value
            portfolio_values.append(portfolio_value)

            # Recalculate portfolio volatility (daily) and store value
            covariance_matrix = returns.iloc[:day].cov(numeric_only = True)
            portfolio_volatility_value = portfolio_volatility(weights, covariance_matrix)
            portfolio_volatilities.append(portfolio_volatility_value)

            #In the next period, optimized weights in this period will be the previous weights
            previous_weights = weights
        else:
            # Calculate portfolio returns(daily)
            portfolio_return = portfolio_gross_return(returns.iloc[day], previous_weights)

            #If there is no rebalancing, there are no transaction costs for this period
            adjusted_return = portfolio_return

            # Store adjusted returns
            adjusted_returns.append(adjusted_return)

            # Update portfolio value
            portfolio_value = portfolio_values[-1] *(1 + adjusted_return)

            # Store portfolio value
            portfolio_values.append(portfolio_value)

            #Calculate the covariance up to this point, to track volatility (even if we do not rebalance we calculate volatility)
            covar_data = returns.iloc[:day]
            covar_matrix = covar_data.cov(numeric_only = True)

            # Recalculate portfolio volatility (daily) and store value
            portfolio_volatility_value = portfolio_volatility(previous_weights, covar_matrix)
            portfolio_volatilities.append(portfolio_volatility_value)

    return portfolio_values, adjusted_returns, portfolio_volatilities

# %%
transaction_rate = 0.01

MVP_portfolio_values, MVP_adjusted_returns, MVP_portfolio_volatilities = backtest_MVP_strategy(df, transaction_rate)
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:520: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:121: RuntimeWarning: divide by zero encountered in divide
#   ret = um.true_divide(
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:121: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py:10474: RuntimeWarning: Degrees of freedom <= 0 for slice
#   base_cov = np.cov(mat.T, ddof=ddof)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2748: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2748: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py:10474: RuntimeWarning: Degrees of freedom <= 0 for slice
#   base_cov = np.cov(mat.T, ddof=ddof)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2748: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2748: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)

# %%
MVP_returns_and_vol = pd.DataFrame({"MVP Portfolio Returns": MVP_adjusted_returns, "MVP Volatility": MVP_portfolio_volatilities })
MVP_returns_and_vol = MVP_returns_and_vol.dropna()
len(MVP_returns_and_vol)
# Out:
# 5092

# %%
MVP_returns_and_vol["Rolling Sharpe Ratio"] = np.sqrt(252)* (MVP_returns_and_vol["MVP Portfolio Returns"].rolling(252).mean() / MVP_returns_and_vol["MVP Volatility"].rolling(252).mean())
MVP_returns_and_vol
# Out:
#       MVP Portfolio Returns  MVP Volatility  Rolling Sharpe Ratio
# 2                  0.007721        0.011441                   NaN
# 3                 -0.006257        0.019683                   NaN
# 4                  0.020144        0.016421                   NaN
# 5                  0.016604        0.020004                   NaN
# 6                 -0.016055        0.019952                   NaN
# ...                     ...             ...                   ...
# 5089               0.069712        0.014136             -0.021866
# 5090              -0.036613        0.014168             -0.221227
# 5091               0.028671        0.014176             -0.105665
# 5092              -0.011943        0.014180             -0.246428
# 5093              -0.051534        0.014180             -0.474643
#
# [5092 rows x 3 columns]

# %% [markdown]
# ## 3.3 Comparison Plots

# %%
#Again we exclude COVID times
plt.plot(MVP_portfolio_values[0:5030], label = "MVP ML", color = "r")
plt.plot(Max_shp_portfolio_values[0:5030], label = "Max Sharpe ML", color = "m")
plt.title("Portfolio Value Over Time")
plt.xlabel("Trading Days")
plt.ylabel("Portfolio Value")
plt.legend()
plt.show()

# %%
print(MVP_portfolio_values[5030])
print(Max_shp_portfolio_values[5030])
# Out:
# 229702.8063843945
# 381492.03523852857

# %%
plt.plot(MVP_portfolio_volatilities, label = "MVP ML", color = "r")
plt.plot(Max_shp_portfolio_volatilities, label = "Max Sharpe ML", color = "m")
plt.title("Evolution of Portfolio Volatility")
plt.xlabel("Trading Days")
plt.ylabel("Volatility of Returns")
plt.ylim(0.004, 0.0225)
plt.legend()
plt.show()

# %%
plt.plot(MVP_returns_and_vol["Rolling Sharpe Ratio"].dropna(), label = "MVP ML", color = "r")
plt.plot(Maxsharpe_returns_and_vol["Rolling Sharpe Ratio"].dropna(), label = "Max Sharpe ML", color = "m")
plt.title("Yearly Rolling Sharpe Ratio")
plt.xlabel("Trading Days")
plt.ylabel("Rolling Sharpe Ratio")
plt.ylim(-3, 6)
plt.legend()
plt.show()
